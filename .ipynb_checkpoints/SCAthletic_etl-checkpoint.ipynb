# %%
import pandas as pd
import sqlalchemy as sql
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSVs into DataFrames

# %%
SCAthletic_file = "./Output/ShopComAthletic.csv"
SCAthletic_df = pd.read_csv(SCAthletic_file)
SCAthletic_df.head()
# Out:
#    Unnamed: 0   ProductID    Price  \
# 0           0  1855904262  185.800
# 1           1  1860265708  119.095
# 2           2  1820031831  128.390
# 3           3  1869256932   54.480
# 4           4  1881421772   78.820
#
#                                                 Name         Brand Gender  \
# 0                   Cougar Women's Vienna-S In Black        Cougar  Women
# 1                   Sam Edelman Women's Pippy Gold M   Sam Edelman  Women
# 2                Tretorn Women's Rawlins 10 in Black       Tretorn  Women
# 3  Steve Madden Womens Tracey Faux Leather Lace-u...  Steve Madden  Women
# 4                 Andrea Conti Women's Dani in White           NaN  Women
#
#                                                Image  \
# 0  https://img.shop.com/Image/260000/267800/26787...
# 1  https://img.shop.com/Image/260000/267800/26787...
# 2  https://img.shop.com/Image/260000/267800/26787...
# 3  https://img.shop.com/Image/270000/273200/27320...
# 4  https://img.shop.com/Image/260000/267800/26787...
#
#                                                  URL
# 0  https://www.shop.com/cougar-womens-vienna-s-in...
# 1  https://www.shop.com/sam-edelman-womens-pippy-...
# 2  https://www.shop.com/tretorn-womens-rawlins-10...
# 3  https://www.shop.com/steve-madden-womens-trace...
# 4  https://www.shop.com/andrea-conti-womens-dani-...

# %%
Nike_file = "./Output/nike.csv"
Nike_df = pd.read_csv(Nike_file)
Nike_df.head()
# Out:
#                                 Name  Price Gender  \
# 0        Nike Blazer Mid '77 Vintage  100.0    Men
# 1                    Nike Air Max 90  120.0    Men
# 2                    Nike Air Max 97  170.0    Men
# 3          Nike Air Vapormax 2021 FK  200.0    Men
# 4  Nike ZoomX Invincible Run Flyknit  180.0    Men
#
#                                                  URL
# 0  https://www.nike.com/t/blazer-mid-77-vintage-m...
# 1  https://www.nike.com/t/air-max-90-mens-shoes-6...
# 2  https://www.nike.com/t/air-max-97-mens-shoe-SD...
# 3  https://www.nike.com/t/air-vapormax-2021-fk-me...
# 4  https://www.nike.com/t/zoomx-invincible-run-fl...

# %% [markdown]
# # Transform DataFrames

# %%
#Clean SCAthletic dataframe to match sql schema
# SCAthletic_dfClean = SCAthletic_df.drop(['Unnamed: 0', 'ProductID', 'Brand', 'Image'], axis = 1)
SCAthletic_dfClean = SCAthletic_dfClean.reset_index()
SCAthletic_dfClean = SCAthletic_dfClean.rename(columns = {'index':'ID'})
SCAthletic_dfClean = SCAthletic_dfClean[['ID', 'Name', 'Price', 'Gender', 'URL']]
SCAthletic_dfClean
# Out:
#         ID    ID                                               Name    Price  \
# 0        0     0                   Cougar Women's Vienna-S In Black  185.800
# 1        1     1                   Sam Edelman Women's Pippy Gold M  119.095
# 2        2     2                Tretorn Women's Rawlins 10 in Black  128.390
# 3        3     3  Steve Madden Womens Tracey Faux Leather Lace-u...   54.480
# 4        4     4                 Andrea Conti Women's Dani in White   78.820
# ...    ...   ...                                                ...      ...
# 8196  8196  8196      Puma Suede PS 50th Gold Gold  367295-01 Kid's   52.000
# 8197  8197  8197  Puma Minions Basket Tongue White-Black-Minion ...   52.000
# 8198  8198  8198  Puma Suede Heart PS Desert Flower/White  36501...   52.000
# 8199  8199  8199  New Balance KL574AIP Grey/Purple/Teal  KL574AI...   35.000
# 8200  8200  8200   New Balance KL574C8G Black/White  KL574C8G Kid's   68.000
#
#      Gender                                                URL
# 0     Women  https://www.shop.com/cougar-womens-vienna-s-in...
# 1     Women  https://www.shop.com/sam-edelman-womens-pippy-...
# 2     Women  https://www.shop.com/tretorn-womens-rawlins-10...
# 3     Women  https://www.shop.com/steve-madden-womens-trace...
# 4     Women  https://www.shop.com/andrea-conti-womens-dani-...
# ...     ...                                                ...
# 8196   Boys  https://www.shop.com/puma-suede-ps-50th-gold-g...
# 8197   Boys  https://www.shop.com/puma-minions-basket-tongu...
# 8198   Boys  https://www.shop.com/puma-suede-heart-ps-deser...
# 8199   Boys  https://www.shop.com/new-balance-kl574aip-grey...
# 8200   Boys  https://www.shop.com/new-balance-kl574c8g-blac...
#
# [8201 rows x 6 columns]

# %%
#Clean Nike dataframe to match sql schema
Nike_dfClean = Nike_df.reset_index()
Nike_dfClean = Nike_dfClean.rename(columns = {'index':'ID'})
Nike_dfClean = Nike_dfClean[['ID', 'Name', 'Price', 'Gender', 'URL']]
Nike_dfClean
# Out:
#         ID                                 Name   Price Gender  \
# 0        0          Nike Blazer Mid '77 Vintage  100.00    Men
# 1        1                      Nike Air Max 90  120.00    Men
# 2        2                      Nike Air Max 97  170.00    Men
# 3        3            Nike Air Vapormax 2021 FK  200.00    Men
# 4        4    Nike ZoomX Invincible Run Flyknit  180.00    Men
# ...    ...                                  ...     ...    ...
# 2185  2185  Nike Jr. Mercurial Vapor 14 Club MG   40.00  Girls
# 2186  2186          Nike Court Borough Low 2 SE   56.97  Girls
# 2187  2187                      Jordan 1 Mid SE   55.00  Girls
# 2188  2188                  Nike Air Max 90 LTR   70.97  Girls
# 2189  2189                   Air Jordan 4 Retro  150.00  Girls
#
#                                                     URL
# 0     https://www.nike.com/t/blazer-mid-77-vintage-m...
# 1     https://www.nike.com/t/air-max-90-mens-shoes-6...
# 2     https://www.nike.com/t/air-max-97-mens-shoe-SD...
# 3     https://www.nike.com/t/air-vapormax-2021-fk-me...
# 4     https://www.nike.com/t/zoomx-invincible-run-fl...
# ...                                                 ...
# 2185  https://www.nike.com/t/jr-mercurial-vapor-14-c...
# 2186  https://www.nike.com/t/court-borough-low-2-se-...
# 2187  https://www.nike.com/t/jordan-1-mid-se-baby-to...
# 2188  https://www.nike.com/t/air-max-90-ltr-baby-tod...
# 2189  https://www.nike.com/t/air-jordan-4-retro-big-...
#
# [2190 rows x 5 columns]

# %% [markdown]
# # Create database connection

# %%
connection_string = "postgres:Payrol662!@localhost:5433/FootwearFinder_db"
engine = create_engine(f'postgresql://{connection_string}')
sql.inspect(engine).get_columns('shopcom')
# Out:
# [{'name': 'ID',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Name',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Price',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Gender',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'URL',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %%
connection_string = "postgres:Payrol662!@localhost:5433/FootwearFinder_db"
engine = create_engine(f'postgresql://{connection_string}')
sql.inspect(engine).get_columns('nike')
# Out:
# [{'name': 'ID',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Name',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Price',
#   'type': DOUBLE_PRECISION(precision=53),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'Gender',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'URL',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %% [markdown]
# # Load DataFrames into database

# %%
SCAthletic_dfClean.to_sql(name='shopcom', con=engine, if_exists='append', index=False)

# %%
Nike_dfClean.to_sql(name='nike', con=engine, if_exists='append', index=False)
